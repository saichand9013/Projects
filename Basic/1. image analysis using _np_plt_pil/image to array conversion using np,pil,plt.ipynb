# %%
import numpy as np

# %%
ones_arr=np.ones((5,5),int)
ones_arr

# %%
ones_arr*255

# %%
import matplotlib.pyplot as plt

# %%
matplotlib inline           # all the graph should keep inside the line

# %%
from PIL import Image       #python imaging library

# %%
elephant_image = Image.open(r'C:\Users\Sai\A in Acodes\data science\projects\Basic\1. image analysis using _np_plt_pil\elephant1.jpg')

# %%
elephant_image

# %%
horse_image = Image.open(r'C:\Users\Sai\A in Acodes\data science\projects\Basic\1. image analysis using _np_plt_pil\horse1.jpg')

# %%
horse_image

# %%
type(horse_image)

# %%
horse_arr=np.asarray(horse_image)
horse_arr

# %%
type(horse_arr)

# %%
plt.imshow(horse_arr)
#plt.show()   for new os

# %%
horse_arr.shape

# %%
horse_red = horse_arr.copy()
horse_red

# %%
horse_arr == horse_red

# %%
plt.imshow(horse_red)
plt.show()

# %%
plt.imshow(horse_red[:,:,0])
plt.show()

# %%
horse_red[:,:,0]

# %%
plt.imshow(horse_red[:,:,0], cmap='Greys')
plt.show()

# %%
plt.imshow(horse_red[:,:,1],cmap='grey')
plt.show()
